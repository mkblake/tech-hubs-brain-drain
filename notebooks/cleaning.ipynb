# %%
import pandas as pd

# %%
msa2000_1 = pd.read_csv('../data/OEWS/2000msa_dl_1.csv')
msa2000_1.head()
# Out:
#   prim_state  area          area_name occ_code  \
# 0         AK   380  Anchorage, AK MSA  11-0000
# 1         AK   380  Anchorage, AK MSA  11-1011
# 2         AK   380  Anchorage, AK MSA  11-1021
# 3         AK   380  Anchorage, AK MSA  11-2011
# 4         AK   380  Anchorage, AK MSA  11-2021
#
#                               occ_titl  group       tot_emp emp_prse   h_mean  \
# 0               Management Occupations  major         10410      4.0    32.84
# 1                     Chief Executives    NaN           480     10.4    51.54
# 2      General and Operations Managers    NaN          3480      4.9    34.81
# 3  Advertising and Promotions Managers    NaN           100     13.1    23.52
# 4                   Marketing Managers    NaN           220     13.0    29.86
#
#       a_mean  ... h_wpct75 h_wpct90 a_wpct10 a_wpct25 a_median a_wpct75  \
# 0      68310  ...    41.76    62.45    31440    42780    61900    86860
# ...

# %%
msa2000_1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 60472 entries, 0 to 60471
# Data columns (total 24 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   prim_state  60472 non-null  object
#  1   area        60472 non-null  int64
#  2   area_name   60472 non-null  object
#  3   occ_code    60472 non-null  object
#  4   occ_titl    60467 non-null  object
#  5   group       3643 non-null   object
#  6   tot_emp     60472 non-null  object
#  7   emp_prse    60472 non-null  object
#  8   h_mean      60472 non-null  object
#  9   a_mean      60472 non-null  object
#  10  mean_prse   60472 non-null  object
#  11  h_wpct10    60472 non-null  object
#  12  h_wpct25    60472 non-null  object
#  13  h_median    60472 non-null  object
#  14  h_wpct75    60472 non-null  object
#  15  h_wpct90    60472 non-null  object
#  16  a_wpct10    60472 non-null  object
#  17  a_wpct25    60472 non-null  object
#  18  a_median    60472 non-null  object
# ...

# %%
msa2000_2 = pd.read_csv('../data/OEWS/2000msa_dl_2.csv')
msa2000_2.head()
# Out:
#   prim_state  area                           area_name occ_code  \
# 0         MS   920  Biloxi-Gulfport-Pascagoula, MS MSA  11-0000
# 1         MS   920  Biloxi-Gulfport-Pascagoula, MS MSA  11-1011
# 2         MS   920  Biloxi-Gulfport-Pascagoula, MS MSA  11-1021
# 3         MS   920  Biloxi-Gulfport-Pascagoula, MS MSA  11-2011
# 4         MS   920  Biloxi-Gulfport-Pascagoula, MS MSA  11-2021
#
#                               occ_titl  group       tot_emp emp_prse   h_mean  \
# 0               Management Occupations  major          8060     12.3    26.37
# 1                     Chief Executives    NaN           400     20.7    45.39
# 2      General and Operations Managers    NaN          2670      9.6    25.33
# 3  Advertising and Promotions Managers    NaN            70     33.4    20.28
# 4                   Marketing Managers    NaN           140     23.3    29.63
#
#       a_mean  ... h_wpct75 h_wpct90 a_wpct10 a_wpct25 a_median a_wpct75  \
# ...

# %%
msa2000_2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 60631 entries, 0 to 60630
# Data columns (total 24 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   prim_state  60631 non-null  object
#  1   area        60631 non-null  int64
#  2   area_name   60631 non-null  object
#  3   occ_code    60631 non-null  object
#  4   occ_titl    60628 non-null  object
#  5   group       3673 non-null   object
#  6   tot_emp     60631 non-null  object
#  7   emp_prse    60631 non-null  object
#  8   h_mean      60631 non-null  object
#  9   a_mean      60631 non-null  object
#  10  mean_prse   60631 non-null  object
#  11  h_wpct10    60631 non-null  object
#  12  h_wpct25    60631 non-null  object
#  13  h_median    60631 non-null  object
#  14  h_wpct75    60631 non-null  object
#  15  h_wpct90    60631 non-null  object
#  16  a_wpct10    60631 non-null  object
#  17  a_wpct25    60631 non-null  object
#  18  a_median    60631 non-null  object
# ...

# %%
commsa2000 = msa2000_1.append(msa2000_2, ignore_index=True, verify_integrity=True, sort=False)
commsa2000.tail()
# Out:
#        prim_state  area         area_name occ_code  \
# 121098         WY  1580  Cheyenne, WY MSA  53-3041
# 121099         WY  1580  Cheyenne, WY MSA  53-7051
# 121100         WY  1580  Cheyenne, WY MSA  53-7061
# 121101         WY  1580  Cheyenne, WY MSA  53-7062
# 121102         WY  1580  Cheyenne, WY MSA  53-7064
#
#                                                  occ_titl group       tot_emp  \
# 121098                        Taxi Drivers and Chauffeurs   NaN           100
# 121099             Industrial Truck and Tractor Operators   NaN            **
# 121100                 Cleaners of Vehicles and Equipment   NaN            50
# 121101  Laborers and Freight, Stock, and Material Move...   NaN           250
# 121102                        Packers and Packagers, Hand   NaN           180
#
#        emp_prse   h_mean     a_mean  ... h_wpct75 h_wpct90 a_wpct10 a_wpct25  \
# 121098     19.5     7.24      15050  ...     8.11     9.43    11790    12850
# ...

# %%
commsa2000 = commsa2000[['prim_state', 'area', 'area_name', 'occ_code', 'occ_titl', 'tot_emp', 'a_mean', 'a_wpct10', 'a_wpct25', 'a_median', 'a_wpct75', 'a_wpct90', 'annual', 'release', 'year']]
commsa2000
# Out:
#        prim_state  area          area_name occ_code  \
# 0              AK   380  Anchorage, AK MSA  11-0000
# 1              AK   380  Anchorage, AK MSA  11-1011
# 2              AK   380  Anchorage, AK MSA  11-1021
# 3              AK   380  Anchorage, AK MSA  11-2011
# 4              AK   380  Anchorage, AK MSA  11-2021
# ...           ...   ...                ...      ...
# 121098         WY  1580   Cheyenne, WY MSA  53-3041
# 121099         WY  1580   Cheyenne, WY MSA  53-7051
# 121100         WY  1580   Cheyenne, WY MSA  53-7061
# 121101         WY  1580   Cheyenne, WY MSA  53-7062
# 121102         WY  1580   Cheyenne, WY MSA  53-7064
#
#                                                  occ_titl       tot_emp  \
# 0                                  Management Occupations         10410
# 1                                        Chief Executives           480
# 2                         General and Operations Managers          3480
# ...

# %%
commsa2000 = commsa2000.loc[commsa2000.occ_code.isin(['11-3021', '13-1081', '13-1111', '13-1161', '15-1211', '15-1212', 
                                                      '15-1221', '15-1231', '15-1232', '15-1241', '15-1244', '15-1245', 
                                                      '15-1251', '15-1256', '15-1257', '15-1299', '15-2031', '15-2041',
                                                      '15-2098', '17-2061', '49-2011'])]
commsa2000
# Out:
#        prim_state  area            area_name occ_code  \
# 8              AK   380    Anchorage, AK MSA  11-3021
# 34             AK   380    Anchorage, AK MSA  13-1111
# 54             AK   380    Anchorage, AK MSA  15-2031
# 275            AK   380    Anchorage, AK MSA  49-2011
# 352            AL   450     Anniston, AL MSA  11-3021
# ...           ...   ...                  ...      ...
# 120467         WV  9000  Wheeling, WV-OH MSA  11-3021
# 120690         WV  9000  Wheeling, WV-OH MSA  49-2011
# 120880         WY  1350       Casper, WY MSA  49-2011
# 120918         WY  1580     Cheyenne, WY MSA  11-3021
# 121068         WY  1580     Cheyenne, WY MSA  49-2011
#
#                                                  occ_titl       tot_emp  \
# 8               Computer and Information Systems Managers           210
# 34                                    Management Analysts           180
# 54                           Operations Research Analysts            40
# ...
